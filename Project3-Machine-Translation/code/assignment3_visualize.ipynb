# %%
import numpy as np
import os
import platform
import pickle
import matplotlib.pyplot as plt

# %%
import pandas as pd
import seaborn as sns

# %%
bleu_df = pd.read_csv("sacrebleu.csv")

# %%
bleu_df.head(5)
# Out:
#    Step  Training Loss  Validation Loss     Bleu
# 0  1000         1.7219         1.382770  28.7245
# 1  1500         1.7506         1.398325  28.7016
# 2  2000         1.9825         1.395685  28.6763
# 3  2500         2.1241         1.389101  28.9019
# 4  3000         2.1783         1.390327  29.0592

# %%
bleu_x = bleu_df["Step"]
bleu_y = bleu_df["Training Loss"]

# %%
bleu_df_x = bleu_df["Step"]
bleu_df_y1 = bleu_df["Training Loss"]
bleu_df_y2 = bleu_df["Validation Loss"]

#一张图里化两条或多条线

plt.figure(dpi=100, figsize=(5, 6))
plt.title('Visualize NMT Loss')
plt.grid(linestyle='-.')
plt.ylim(1,3)
plt.plot(bleu_df_x,bleu_df_y1)
plt.plot(bleu_df_x,bleu_df_y2)
plt.show()

# %%
bleu_df_x = bleu_df["Step"]
bleu_df_y1 = bleu_df["Bleu"]
# bleu_df_y2 = bleu_df["Validation Loss"]
plt.figure(dpi=100, figsize=(15, 6))
plt.title('Visualize Bleu')
plt.grid(linestyle='-.')
plt.ylim(26,30)
plt.plot(bleu_df_x,bleu_df_y1)
# plt.plot(bleu_df_x,bleu_df_y2)
plt.show()
